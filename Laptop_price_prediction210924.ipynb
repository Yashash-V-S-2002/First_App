# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/My_course_data_science/Machine Learning/laptop_price.csv",encoding="latin")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=["laptop_ID"],inplace=True)

# %%
df.head(5)
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# ...

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Price"]=round(df["Price_euros"]*93.25184).astype("int")

# %%
df.drop(columns=["Price_euros"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price             1275 non-null   int64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 119.7+ KB

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  124929
# ...

# %%
df["Price"].describe()
# Out:
# count      1275.000000
# mean     105837.960000
# std       65346.456907
# min       16226.000000
# 25%       56790.000000
# 50%       92226.000000
# 75%      139551.500000
# max      568743.000000
# Name: Price, dtype: float64

# %%
sns.kdeplot(df["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df["Price"].skew()
# Out:
# 1.5111472496205085

# %%
df["Price"].kurtosis()
# Out:
# 4.3408196587754455

# %%
sns.kdeplot(np.log(df["Price"]))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
# EDA and Feature Engineering

# %%
# Company

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation="vertical")
plt.show()

# %%
df.groupby("Company").Company.transform("count")>20
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1270    True
# 1271    True
# 1272    True
# 1273    True
# 1274    True
# Name: Company, Length: 1275, dtype: bool

# %%
df=df[df.groupby("Company").Company.transform("count")>20]

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1219  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1220  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1221  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1222      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1223    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df["Company"],y=df["Price"],errorbar=None)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
company_sorted_price=df.groupby("Company")["Price"].mean().sort_values(ascending=False).index

# %%
sns.barplot(x=df["Company"],y=df["Price"],errorbar=None,order=company_sorted_price)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
#Product

# %%
df["Product"].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=["Product"],inplace=True)
# Out:
# <ipython-input-37-96b0751ad64e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Product"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  124929
# 1        Intel HD Graphics 6000  macOS  1.34kg   83828
# 2         Intel HD Graphics 620  No OS  1.86kg   53620
# ...

# %%
#TypeName

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
df.groupby("TypeName")["Price"].mean()
# Out:
# TypeName
# 2 in 1 Convertible    121177.973684
# Gaming                155888.190000
# Netbook                64508.318182
# Notebook               74219.122093
# Ultrabook             144559.666667
# Workstation           212647.689655
# Name: Price, dtype: float64

# %%
a=df.groupby("TypeName")["Price"].mean().sort_values(ascending=False).index
sns.barplot(x=df["TypeName"],y=df["Price"],errorbar=None,order=a,palette="summer")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-43-cb3372cf05e0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["TypeName"],y=df["Price"],errorbar=None,order=a,palette="summer")

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
#Inches

# %%
df["Inches"].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.displot(x=df["Inches"],kde=True)

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
#ScreenResolution

# %%
print(df["ScreenResolution"].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
a="IPS Panel Full HD / Touchscreen 1920x1080"

# %%
a.split()
# Out:
# ['IPS', 'Panel', 'Full', 'HD', '/', 'Touchscreen', '1920x1080']

# %%
a.split()[-1]
# Out:
# '1920x1080'

# %%
a.split()[-1].split("x")
# Out:
# ['1920', '1080']

# %%
a.split()[-1].split("x")[0]
# Out:
# '1920'

# %%
int(a.split()[-1].split("x")[0])
# Out:
# 1920

# %%
(lambda a:int(a.split()[-1].split("x")[0]))("Quad HD+ / Touchscreen 3200x1800")
# Out:
# 3200

# %%
df.loc[:,"X_res"]=df["ScreenResolution"].apply(lambda a:int(a.split()[-1].split("x")[0]))
df.loc[:,"Y_res"]=df["ScreenResolution"].apply(lambda a:int(a.split()[-1].split("x")[1]))
# Out:
# <ipython-input-58-3d65dffe732b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,"X_res"]=df["ScreenResolution"].apply(lambda a:int(a.split()[-1].split("x")[0]))
# <ipython-input-58-3d65dffe732b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,"Y_res"]=df["ScreenResolution"].apply(lambda a:int(a.split()[-1].split("x")[1]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  X_res  Y_res
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  124929   2560   1600
# 1        Intel HD Graphics 6000  macOS  1.34kg   83828   1440    900
# ...

# %%
lambda x:1 if "IPS" in x else 0
lambda x:1 if "Touchscreen" in x else 0
# Out:
# <function __main__.<lambda>(x)>

# %%
df.loc[:,"IPS"]=df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)
df.loc[:,"Touchscreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)
# Out:
# <ipython-input-61-ffd04f88f820>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,"IPS"]=df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)
# <ipython-input-61-ffd04f88f820>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,"Touchscreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1219  Lenovo  2 in 1 Convertible    14.0
# 1220  Lenovo  2 in 1 Convertible    13.3
# 1221  Lenovo            Notebook    14.0
# 1222      HP            Notebook    15.6
# 1223    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# 1220  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 202    Acer   Notebook    15.6            Full HD 1920x1080
# 847  Lenovo   Notebook    17.3                     1600x900
# 354      HP   Notebook    15.6            Full HD 1920x1080
# 754    Asus     Gaming    15.6            Full HD 1920x1080
# 783  Lenovo  Ultrabook    14.0  IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 202  Intel Core i7 7700HQ 2.8GHz  8GB               1TB HDD
# 847    AMD A4-Series 7210 2.2GHz  4GB             500GB HDD
# 354   Intel Core i5 7200U 2.5GHz  8GB               1TB HDD
# 754  Intel Core i7 7700HQ 2.8GHz  8GB  128GB SSD +  1TB HDD
# 783   Intel Core i7 7500U 2.7GHz  8GB             512GB SSD
#
#                          Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 202  Nvidia GeForce GTX 1050       Linux   2.4kg   72643   1920   1080    0
# 847            AMD Radeon R3  Windows 10   2.8kg   35342   1600    900    0
# ...

# %%
df.drop(columns=["ScreenResolution"],inplace=True)
# Out:
# <ipython-input-64-047785755b9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["ScreenResolution"],inplace=True)

# %%
df.sample()
# Out:
#     Company   TypeName  Inches                         Cpu  Ram     Memory  \
# 804      HP  Ultrabook    14.0  Intel Core i7 6500U 2.5GHz  8GB  512GB SSD
#
#                        Gpu      OpSys  Weight   Price  X_res  Y_res  IPS  \
# 804  Intel HD Graphics 520  Windows 7  1.54kg  174381   1920   1080    0
#
#      Touchscreen
# 804            0

# %%
#Ram

# %%
x="4GB"

# %%
x.replace("GB","")
# Out:
# '4'

# %%
int(x.replace("GB",""))
# Out:
# 4

# %%
(lambda x:int(x.replace("GB","")))("100GB")
# Out:
# 100

# %%
df["Ram"]=df["Ram"].apply(lambda x:int(x.replace("GB","")))
# Out:
# <ipython-input-71-2ff0b4f77709>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ram"]=df["Ram"].apply(lambda x:int(x.replace("GB","")))

# %%
df.sample()
# Out:
#     Company            TypeName  Inches                         Cpu  Ram  \
# 843      HP  2 in 1 Convertible    13.3  Intel Core i5 7200U 2.5GHz    4
#
#         Memory                    Gpu       OpSys  Weight   Price  X_res  \
# 843  256GB SSD  Intel HD Graphics 620  Windows 10  1.28kg  167760   1920
#
#      Y_res  IPS  Touchscreen
# 843   1080    0            1

# %%
#Weight

# %%
df["Weight"]=df["Weight"].apply(lambda x:float(x.replace("kg","")))
# Out:
# <ipython-input-74-4d5ae7034b48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Weight"]=df["Weight"].apply(lambda x:float(x.replace("kg","")))

# %%
df.sample()
# Out:
#      Company  TypeName  Inches                          Cpu  Ram   Memory  \
# 1135      HP  Notebook    15.6  Intel Core i7 6700HQ 2.6GHz    6  1TB HDD
#
#                           Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  \
# 1135  Nvidia GeForce GTX 960M  Windows 10    2.18  74508   1920   1080    1
#
#       Touchscreen
# 1135            0

# %%
print(df.dtypes)
# Out:
# Company         object
# TypeName        object
# Inches         float64
# Cpu             object
# Ram              int64
# Memory          object
# Gpu             object
# OpSys           object
# Weight         float64
# Price            int64
# X_res            int64
# Y_res            int64
# IPS              int64
# Touchscreen      int64
# dtype: object

# %%
#IPS

# %%
df["IPS"].value_counts()
# Out:
# IPS
# 0    885
# 1    339
# Name: count, dtype: int64

# %%
df["IPS"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df["IPS"],y=df["Price"])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
#Touchscreen

# %%
df["Touchscreen"].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df["Touchscreen"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df["Touchscreen"],y=df["Price"])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
#RAM

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df["Ram"],y=df["Price"],errorbar=None,palette="summer",hue=df["Ram"],legend=False)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
#weight

# %%
df["Weight"].describe()
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
sns.displot(x=df["Weight"],kde=True)

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=df["Weight"],y=df["Price"],hue=df["TypeName"],palette="husl")
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
#CPU

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
df["Cpu_speed_GHz"]=df["Cpu"].apply(lambda x:x.split()[-1].replace("GHz","")).astype("float")
# Out:
# <ipython-input-95-a1b3b91b3dc8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu_speed_GHz"]=df["Cpu"].apply(lambda x:x.split()[-1].replace("GHz","")).astype("float")

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                         Cpu  Ram     Memory  \
# 301  Lenovo  Notebook    13.3  Intel Core i5 7200U 2.5GHz    8  256GB SSD
#
#                        Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  \
# 301  Intel HD Graphics 620  Windows 10     1.1  93159   1920   1080    1
#
#      Touchscreen  Cpu_speed_GHz
# 301            0            2.5

# %%
a="Intel Core i5 8250U 1.6GHz"
a.split()[:-1]
# Out:
# ['Intel', 'Core', 'i5', '8250U']

# %%
" ".join(a.split()[:-1])
# Out:
# 'Intel Core i5 8250U'

# %%
df["Cpu"]=df["Cpu"].apply(lambda a:" ".join(a.split()[:-1]))
# Out:
# <ipython-input-99-fa8360b959be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu"]=df["Cpu"].apply(lambda a:" ".join(a.split()[:-1]))

# %%
df.sample()
# Out:
#     Company TypeName  Inches                   Cpu  Ram     Memory  \
# 784     MSI   Gaming    15.6  Intel Core i5 7300HQ    8  256GB SSD
#
#                          Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 784  Nvidia GeForce GTX 1050  Windows 10     2.4  111809   1920   1080    0
#
#      Touchscreen  Cpu_speed_GHz
# 784            0            2.5

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U     186
# Intel Core i7 7700HQ    143
# Intel Core i7 7500U     124
# Intel Core i3 6006U      81
# Intel Core i7 8550U      71
#                        ...
# Intel Core M 7Y30         1
# Intel Core i5 6440HQ      1
# Intel Core i5 7500U       1
# AMD Ryzen 1600            1
# AMD A9-Series 9410        1
# Name: count, Length: 87, dtype: int64

# %%
df["Cpu"]=df["Cpu"].apply(lambda a:" ".join(a.split()[:3]))
# Out:
# <ipython-input-102-80655f77ad23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu"]=df["Cpu"].apply(lambda a:" ".join(a.split()[:3]))

# %%
print(df["Cpu"].value_counts())
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# ...

# %%
def fetch_processor(text):
    if text=="Intel Core i7" or text=="Intel Core i5" or text=="Intel Core i3" or text=="Intel Core M":
        return text
    elif text.split()[0]=="Intel":
        return " ".join(text.split()[0:2])
    else:
        return "AMD "+str(text[4])+"-Series"

# %%
print(df["Cpu"].apply(fetch_processor))
# Out:
# 0       Intel Core i5
# 1       Intel Core i5
# 2       Intel Core i5
# 3       Intel Core i7
# 4       Intel Core i5
#             ...
# 1219    Intel Core i7
# 1220    Intel Core i7
# 1221    Intel Celeron
# 1222    Intel Core i7
# 1223    Intel Celeron
# Name: Cpu, Length: 1224, dtype: object

# %%
df["Cpu"]=df["Cpu"].apply(fetch_processor)
# Out:
# <ipython-input-106-0bf72fbee4f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cpu"]=df["Cpu"].apply(fetch_processor)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram     Memory  \
# 119  Lenovo  Notebook    15.6  Intel Core i5    8  256GB SSD
#
#                       Gpu  OpSys  Weight  Price  X_res  Y_res  IPS  \
# 119  Nvidia GeForce 940MX  No OS     2.2  58655   1920   1080    0
#
#      Touchscreen  Cpu_speed_GHz
# 119            0            2.5

# %%
print(df["Cpu"].value_counts())
# Out:
# Cpu
# Intel Core i7    493
# Intel Core i5    411
# Intel Core i3    134
# Intel Celeron     71
# AMD A-Series      45
# Intel Pentium     30
# Intel Core M      16
# AMD E-Series       9
# Intel Atom         5
# AMD R-Series       4
# Intel Xeon         4
# AMD F-Series       2
# Name: count, dtype: int64

# %%
df["Cpu"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cpu'>

# %%
a=df.groupby("Cpu")["Price"].mean().sort_values(ascending=False).index
a
# Out:
# Index(['Intel Xeon', 'AMD R-Series', 'Intel Core i7', 'Intel Core M',
#        'Intel Core i5', 'AMD F-Series', 'Intel Core i3', 'AMD A-Series',
#        'Intel Atom', 'Intel Pentium', 'Intel Celeron', 'AMD E-Series'],
#       dtype='object', name='Cpu')

# %%
sns.barplot(x=df["Cpu"],y=df["Price"],errorbar=None,order=a,palette="summer")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-111-fb078d4232bf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Cpu"],y=df["Price"],errorbar=None,order=a,palette="summer")

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5    8            256GB SSD
# 3   Apple  Ultrabook    15.4  Intel Core i7   16            512GB SSD
# 4   Apple  Ultrabook    13.3  Intel Core i5    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  X_res  Y_res  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  124929   2560   1600    1
# 1        Intel HD Graphics 6000  macOS    1.34   83828   1440    900    0
# 2         Intel HD Graphics 620  No OS    1.86   53620   1920   1080    0
# 3            AMD Radeon Pro 455  macOS    1.83  236622   2880   1800    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  168189   2560   1600    1
#
#    Touchscreen  Cpu_speed_GHz
# 0            0            2.3
# 1            0            1.8
# ...

# %%
#Cpu_speed_GHz

# %%
sns.displot(x=df["Cpu_speed_GHz"],kde=True)

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x=df["Cpu_speed_GHz"],y=df["Price"],hue=df["Cpu"],palette="husl")
plt.xticks(np.arange(0.9,3.7,0.1))
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram            0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight         0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price          0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res         -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res         -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# IPS           -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# Cpu_speed_GHz  0.296510  0.356482  0.313267  0.422535  0.187056  0.178539
#
#                     IPS  Touchscreen  Cpu_speed_GHz
# Inches        -0.104090    -0.359497       0.296510
# Ram            0.223322     0.094037       0.356482
# Weight         0.038753    -0.291506       0.313267
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),cmap="summer")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram               Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5    8            256GB SSD
# 3   Apple  Ultrabook    15.4  Intel Core i7   16            512GB SSD
# 4   Apple  Ultrabook    13.3  Intel Core i5    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  X_res  Y_res  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  124929   2560   1600    1
# 1        Intel HD Graphics 6000  macOS    1.34   83828   1440    900    0
# 2         Intel HD Graphics 620  No OS    1.86   53620   1920   1080    0
# 3            AMD Radeon Pro 455  macOS    1.83  236622   2880   1800    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37  168189   2560   1600    1
#
#    Touchscreen  Cpu_speed_GHz
# 0            0            2.3
# 1            0            1.8
# ...

# %%
#Gpu

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df["Gpu_temp"]=df["Gpu"].apply(lambda x:" ".join(x.split()[:2]))
# Out:
# <ipython-input-121-5c703d464fac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gpu_temp"]=df["Gpu"].apply(lambda x:" ".join(x.split()[:2]))

# %%
print(df["Gpu_temp"].value_counts())
# Out:
# Gpu_temp
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# AMD R4              1
# Nvidia GTX          1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def fetch_gpu(text):
    if text.split()[0]=="AMD":
        return "AMD Gpu"
    elif text=="Intel HD" or text=="Nvidia GeForce" or text=="Intel UHD" or text=="Nvidia Quadro" or text=="Intel Iris":
        return text
    elif text=="Nvidia GTX":
        return "Nvidia GeForce"
    elif text=="Intel Graphics":
        return "Intel HD"

# %%
df["Gpu_temp"]=df["Gpu_temp"].apply(fetch_gpu)
# Out:
# <ipython-input-124-68acf4edb4c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gpu_temp"]=df["Gpu_temp"].apply(fetch_gpu)

# %%
df["Gpu_temp"].value_counts()
# Out:
# Gpu_temp
# Intel HD          587
# Nvidia GeForce    354
# AMD Gpu           173
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# Name: count, dtype: int64

# %%
df["Gpu"]=df["Gpu_temp"]
# Out:
# <ipython-input-126-3a01dca9a54e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gpu"]=df["Gpu_temp"]

# %%
df.drop(columns=["Gpu_temp"],inplace=True)
# Out:
# <ipython-input-127-28a726ddd07f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Gpu_temp"],inplace=True)

# %%
df["Gpu"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gpu'>

# %%
a=df.groupby("Gpu")["Price"].mean().sort_values(ascending=False)
print(a)
# Out:
# Gpu
# Nvidia Quadro     229260.516129
# Intel Iris        161213.000000
# Nvidia GeForce    128503.240113
# Intel UHD         112440.147059
# Intel HD           91801.521295
# AMD Gpu            72002.098266
# Name: Price, dtype: float64

# %%
sns.barplot(x=df["Gpu"],y=df["Price"],errorbar=None,palette="winter",order=a.index)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-130-43000f0fef36>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df["Gpu"],y=df["Price"],errorbar=None,palette="winter",order=a.index)

# %%
#OpSys

# %%
print(df["OpSys"].value_counts())
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def fetch_os(text):
    if text=="Windows 10" or text=="Windows 10 S":
        return "Windows 10"
    elif text=="macOS" or text=="Mac OS X":
        return "MacOS"
    elif text=="No OS" or text=="Windows 7":
        return text
    else:
        return "Linux/Chrome OS/Others"

# %%
df["OpSys"]=df["OpSys"].apply(fetch_os)
# Out:
# <ipython-input-134-9c1f5dcb5e08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["OpSys"]=df["OpSys"].apply(fetch_os)

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10                1013
# Linux/Chrome OS/Others      82
# No OS                       63
# Windows 7                   45
# MacOS                       21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='OpSys'>

# %%
a=df.groupby("OpSys")["Price"].mean().sort_values(ascending=False)
print(a)
# Out:
# OpSys
# Windows 7                 157283.377778
# MacOS                     145864.428571
# Windows 10                109233.929911
# Linux/Chrome OS/Others     52223.426829
# No OS                      52113.571429
# Name: Price, dtype: float64

# %%
palette=sns.color_palette("summer",len(a))
palette_dict=dict(zip(a.index,palette))
palette_dict
# Out:
# {'Windows 7': (0.16470588235294117, 0.5823529411764706, 0.4),
#  'MacOS': (0.3333333333333333, 0.6666666666666666, 0.4),
#  'Windows 10': (0.5019607843137255, 0.7509803921568627, 0.4),
#  'Linux/Chrome OS/Others': (0.6666666666666666, 0.8333333333333333, 0.4),
#  'No OS': (0.8352941176470589, 0.9176470588235295, 0.4)}

# %%
sns.barplot(x=df["OpSys"],y=df["Price"],errorbar=None,order=a.index,palette=palette_dict,hue=df["OpSys"])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#    Company  TypeName  Inches            Cpu  Ram   Memory             Gpu  \
# 18  Lenovo  Notebook    15.6  Intel Core i3    8  1TB HDD  Nvidia GeForce
#
#     OpSys  Weight  Price  X_res  Y_res  IPS  Touchscreen  Cpu_speed_GHz
# 18  No OS     2.2  46533   1920   1080    0            0            2.4

# %%
print(df["Memory"].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# ...

# %%
df["Memory"]=df["Memory"].astype("str").replace("\.0","",regex=True)
# Out:
# <ipython-input-142-47ed017d07cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].astype("str").replace("\.0","",regex=True)

# %%
df["Memory"]=df["Memory"].str.replace("GB","")
df["Memory"]=df["Memory"].str.replace("TB","000")
# Out:
# <ipython-input-143-c5c4cfd7a221>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].str.replace("GB","")
# <ipython-input-143-c5c4cfd7a221>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].str.replace("TB","000")

# %%
print(df["Memory"].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 16 SSD                            3
# 512 SSD +  2000 HDD               3
# 1000 SSD +  1000 HDD              2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 256 SSD +  500 HDD                2
# 256 SSD +  256 SSD                2
# 32 SSD                            2
# ...

# %%
new=df["Memory"].str.split("+",n=1,expand=True)
df["first"]=new[0]
df["first"]=df["first"].str.strip()
df["second"]=new[1]
# Out:
# <ipython-input-145-8cce20100c61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"]=new[0]
# <ipython-input-145-8cce20100c61>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"]=df["first"].str.strip()
# <ipython-input-145-8cce20100c61>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-146-4978ec531ce1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
# <ipython-input-146-4978ec531ce1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
# <ipython-input-146-4978ec531ce1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram    Memory  \
# 810       HP            Notebook    15.6  Intel Celeron    4   128 SSD
# 73      Asus              Gaming    15.6  Intel Core i7    8  1000 HDD
# 286   Lenovo              Gaming    15.6  Intel Core i7    8  1000 HDD
# 394     Acer            Notebook    15.6  Intel Core i7    8   256 SSD
# 1093      HP  2 in 1 Convertible    13.3  Intel Core i5    8   256 SSD
#
#                  Gpu                   OpSys  Weight   Price  ...  Y_res  IPS  \
# 810         Intel HD                   No OS    1.86   27882  ...    768    0
# 73    Nvidia GeForce              Windows 10    2.20   88496  ...   1080    0
# 286   Nvidia GeForce              Windows 10    3.20  121134  ...   1080    1
# 394   Nvidia GeForce  Linux/Chrome OS/Others    2.50   81968  ...   1080    0
# 1093        Intel HD              Windows 10    1.48  151907  ...   1080    0
#
# ...

# %%
df['first']=df['first'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-148-043ccd27c636>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=df['first'].str.replace(r'\D','',regex=True)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 1119      HP            Notebook    14.0  Intel Celeron    2
# 872      MSI              Gaming    17.3  Intel Core i7   16
# 178   Lenovo  2 in 1 Convertible    13.9  Intel Core i7   16
# 279   Lenovo              Gaming    15.6  Intel Core i7   16
# 953       HP           Ultrabook    14.0  Intel Core i7    8
#
#                    Memory             Gpu       OpSys  Weight   Price  ...  \
# 1119     32 Flash Storage        Intel HD  Windows 10    1.44   23220  ...
# 872   256 SSD +  1000 HDD  Nvidia GeForce  Windows 10    2.70  149110  ...
# 178               512 SSD       Intel UHD  Windows 10    1.40  172423  ...
# 279   256 SSD +  1000 HDD  Nvidia GeForce  Windows 10    2.50  109944  ...
# 953               512 SSD        Intel HD  Windows 10    1.48  194803  ...
#
#       Y_res  IPS  Touchscreen  Cpu_speed_GHz  first      second Layer1HDD  \
# ...

# %%
df['second'].fillna("0",inplace=True)
df['second']=df['second'].str.strip()
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-150-c9a3fdf9c4d1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['second'].fillna("0",inplace=True)
# <ipython-input-150-c9a3fdf9c4d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'].fillna("0",inplace=True)
# <ipython-input-150-c9a3fdf9c4d1>:2: SettingWithCopyWarning:
# ...

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches            Cpu  Ram             Memory  \
# 220      HP   Notebook    15.6  Intel Core i7    8           1000 HDD
# 950      HP  Ultrabook    13.3  Intel Core i7    8            256 SSD
# 584    Acer   Notebook    14.0  Intel Pentium    4  128 Flash Storage
# 166      HP   Notebook    13.3  Intel Core i5    4            500 HDD
# 496    Asus    Netbook    11.6  Intel Celeron    2   32 Flash Storage
#
#            Gpu       OpSys  Weight   Price  ...  first  second  Layer1HDD  \
# 220    AMD Gpu  Windows 10    1.90  118337  ...   1000       0          1
# 950   Intel HD  Windows 10    1.11  125797  ...    256       0          0
# 584   Intel HD  Windows 10    1.60   32545  ...    128       0          0
# 166  Intel UHD  Windows 10    1.49   70312  ...    500       0          1
# 496   Intel HD  Windows 10    1.10   22847  ...     32       0          0
#
#      Layer1SSD  Layer1Hybrid Layer1Flash Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df['second']=df['second'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-152-7e4a144e1deb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=df['second'].str.replace(r'\D','',regex=True)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches            Cpu  Ram               Memory  \
# 544     Dell  Ultrabook    13.3  Intel Core i5    8              128 SSD
# 831   Lenovo   Notebook    15.6  Intel Core i3    4             1000 HDD
# 1190    Asus  Ultrabook    13.3  Intel Core i7    8              256 SSD
# 403       HP   Notebook    15.6  Intel Core i3    4             1000 HDD
# 894     Dell     Gaming    17.3  Intel Core i7   16  512 SSD +  1000 HDD
#
#                  Gpu       OpSys  Weight   Price  ...  first  second  \
# 544        Intel UHD  Windows 10    1.21  149110  ...    128       0
# 831          AMD Gpu       No OS    2.20   44668  ...   1000       0
# 1190        Intel HD  Windows 10    1.45  119362  ...    256       0
# 403          AMD Gpu  Windows 10    2.10   43735  ...   1000       0
# 894   Nvidia GeForce  Windows 10    4.36  257189  ...    512    1000
#
#       Layer1HDD  Layer1SSD  Layer1Hybrid Layer1Flash Layer2HDD  Layer2SSD  \
# ...

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')
# Out:
# <ipython-input-154-985d4fe1ffcd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=df['first'].astype('int')
# <ipython-input-154-985d4fe1ffcd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=df['second'].astype('int')

# %%
df.sample(5)
# Out:
#      Company     TypeName  Inches            Cpu  Ram    Memory  \
# 987       HP     Notebook    14.0  Intel Core i5    8   256 SSD
# 620  Toshiba     Notebook    13.3  Intel Core i5    8   256 SSD
# 135   Lenovo     Notebook    15.6  Intel Core i5    4  1000 HDD
# 119   Lenovo     Notebook    15.6  Intel Core i5    8   256 SSD
# 662       HP  Workstation    17.3  Intel Core i7    8   500 HDD
#
#                 Gpu       OpSys  Weight   Price  ...  first  second  \
# 987        Intel HD   Windows 7    1.95  111436  ...    256       0
# 620        Intel HD  Windows 10    1.20  113114  ...    256       0
# 135  Nvidia GeForce       No OS    2.20   46533  ...   1000       0
# 119  Nvidia GeForce       No OS    2.20   58655  ...    256       0
# 662   Nvidia Quadro  Windows 10    3.14  177924  ...    500       0
#
#      Layer1HDD  Layer1SSD  Layer1Hybrid  Layer1Flash  Layer2HDD  Layer2SSD  \
# 987          0          1             0            0          0          0
# ...

# %%
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']
# Out:
# <ipython-input-156-ab0518cd5d0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
# <ipython-input-156-ab0518cd5d0c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
# <ipython-input-156-ab0518cd5d0c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches            Cpu  Ram               Memory  \
# 924   Lenovo   Notebook    15.6  Intel Core i5    6              256 SSD
# 655     Dell     Gaming    15.6  Intel Core i7   16  256 SSD +  1000 HDD
# 1191    Acer   Notebook    15.6  Intel Core i3    4              500 HDD
# 913     Dell  Ultrabook    13.3  Intel Core i7    8              256 SSD
# 445     Acer    Netbook    11.6  Intel Celeron    4              128 SSD
#
#                  Gpu                   OpSys  Weight   Price  ...  \
# 924   Nvidia GeForce              Windows 10    2.40   64810  ...
# 655   Nvidia GeForce              Windows 10    3.49  262387  ...
# 1191        Intel HD  Linux/Chrome OS/Others    2.40   33739  ...
# 913         Intel HD              Windows 10    1.30  118243  ...
# 445         Intel HD              Windows 10    1.40   40565  ...
#
#       Layer1Hybrid  Layer1Flash  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash'],inplace=True)
# Out:
# <ipython-input-158-181153d3af2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches            Cpu  Ram  \
# 1041      HP            Notebook    13.3  Intel Pentium    4
# 1097      HP           Ultrabook    12.5  Intel Core i7    8
# 191       HP            Notebook    17.3  Intel Core i7    8
# 1118  Lenovo            Notebook    15.6  Intel Core i3    4
# 305     Asus  2 in 1 Convertible    11.6  Intel Celeron    2
#
#                 Memory             Gpu                   OpSys  Weight  \
# 1041  32 Flash Storage        Intel HD  Linux/Chrome OS/Others    1.29
# 1097           256 SSD        Intel HD               Windows 7    1.26
# 191            256 SSD  Nvidia GeForce              Windows 10    2.50
# 1118          1000 HDD  Nvidia GeForce              Windows 10    2.20
# 305   32 Flash Storage        Intel HD              Windows 10    1.10
#
#        Price  X_res  Y_res  IPS  Touchscreen  Cpu_speed_GHz   HDD  SSD  \
# 1041   57350   3200   1800    0            0            1.5     0    0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-160-8cab1fd6fcc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Memory'],inplace=True)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches            Cpu  Ram             Gpu  \
# 188       HP  Notebook    17.3  Intel Core i5    8  Nvidia GeForce
# 1120     MSI    Gaming    15.6  Intel Core i7    8  Nvidia GeForce
# 331     Dell  Notebook    15.6  Intel Celeron    4        Intel HD
#
#                        OpSys  Weight  Price  X_res  Y_res  IPS  Touchscreen  \
# 188               Windows 10     2.5  85232   1920   1080    1            0
# 1120              Windows 10     2.2  78238   1920   1080    1            0
# 331   Linux/Chrome OS/Others     2.2  25635   1366    768    0            0
#
#       Cpu_speed_GHz   HDD  SSD  Hybrid  Flash_Storage
# 188             1.6  1000    0       0              0
# 1120            2.7  1000    0       0              0
# 331             1.6   500    0       0              0

# %%
print(df.corr(numeric_only=True)["Price"])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# Price            1.000000
# X_res            0.553707
# Y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed_GHz    0.422535
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# Name: Price, dtype: float64

# %%
df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)
# Out:
# <ipython-input-163-fffb082a59a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Hybrid","Flash_Storage"],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram             Gpu       OpSys  \
# 515    Dell  Notebook    15.6  Intel Core i7    8  Nvidia GeForce  Windows 10
#
#      Weight   Price  X_res  Y_res  IPS  Touchscreen  Cpu_speed_GHz  HDD  SSD
# 515    1.93  127662   1920   1080    0            0            2.8    0  256

# %%
#HDD n SDD

# %%
df["HDD"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='HDD'>

# %%
sns.barplot(x=df["HDD"],y=df["Price"])
# Out:
# <Axes: xlabel='HDD', ylabel='Price'>

# %%
df["SSD"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='SSD'>

# %%
sns.barplot(x=df["SSD"],y=df["Price"])
# Out:
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
#Pixel Density

# %%
df["PPI"]=(((df["X_res"]**2)+(df["Y_res"]**2))**0.5/df["Inches"]).astype("int")
# Out:
# <ipython-input-171-13f628f481b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PPI"]=(((df["X_res"]**2)+(df["Y_res"]**2))**0.5/df["Inches"]).astype("int")

# %%
print(df.corr(numeric_only=True)["Price"])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# Price            1.000000
# X_res            0.553707
# Y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed_GHz    0.422535
# HDD             -0.093770
# SSD              0.654751
# PPI              0.483532
# Name: Price, dtype: float64

# %%
df.drop(columns=["Inches","X_res","Y_res"],inplace=True)
# Out:
# <ipython-input-173-5a1e1708d7a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Inches","X_res","Y_res"],inplace=True)

# %%
#PPI

# %%
df["PPI"].value_counts()
# Out:
# PPI
# 141    419
# 100    195
# 127    135
# 157    122
# 165    100
# 111     43
# 135     28
# 276     25
# 176     25
# 282     23
# 106     22
# 209     18
# 226     12
# 125      9
# 117      8
# 331      7
# 220      6
# 254      5
# 224      4
# 158      4
# 169      2
# 316      2
# 352      2
# 90       2
# 119      1
# 189      1
# 107      1
# 194      1
# 234      1
# 146      1
# Name: count, dtype: int64

# %%
sns.histplot(x=df["PPI"],kde=True)
# Out:
# <Axes: xlabel='PPI', ylabel='Count'>

# %%
sns.scatterplot(x=df["PPI"],y=df["Price"])
# Out:
# <Axes: xlabel='PPI', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName            Cpu  Ram         Gpu  OpSys  Weight   Price  \
# 0   Apple  Ultrabook  Intel Core i5    8  Intel Iris  MacOS    1.37  124929
# 1   Apple  Ultrabook  Intel Core i5    8    Intel HD  MacOS    1.34   83828
# 2      HP   Notebook  Intel Core i5    8    Intel HD  No OS    1.86   53620
# 3   Apple  Ultrabook  Intel Core i7   16     AMD Gpu  MacOS    1.83  236622
# 4   Apple  Ultrabook  Intel Core i5    8  Intel Iris  MacOS    1.37  168189
#
#    IPS  Touchscreen  Cpu_speed_GHz  HDD  SSD  PPI
# 0    1            0            2.3    0  128  226
# 1    0            0            1.8    0    0  127
# 2    0            0            2.5    0  256  141
# 3    1            0            2.7    0  512  220
# 4    1            0            3.1    0  256  226

# %%
df.to_csv("laptop_data_processed.csv",index=False)

# %%
#Machine learning process

# %%
X=df.drop(columns=["Price"])
y=df["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=36,stratify=df['Cpu'])

# %%
X_train.shape,X_test.shape
# Out:
# ((1040, 13), (184, 13))

# %%
X_train.head()
# Out:
#      Company  TypeName            Cpu  Ram             Gpu       OpSys  \
# 1129     MSI    Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10
# 215     Dell    Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10
# 871       HP  Notebook  Intel Core i5    8        Intel HD  Windows 10
# 409     Dell  Notebook  Intel Core i5    8        Intel HD  Windows 10
# 293   Lenovo  Notebook  Intel Core i5    6  Nvidia GeForce  Windows 10
#
#       Weight  IPS  Touchscreen  Cpu_speed_GHz   HDD  SSD  PPI
# 1129    1.91    0            0            2.6  1000  128  141
# 215     4.42    1            0            2.8  1000  256  127
# 871     1.49    0            0            2.5     0  256  165
# 409     2.14    0            0            2.5  1000    0  100
# 293     2.80    0            0            2.5  1000    0  106

# %%
y_train.head()
# Out:
# 1129    200806
# 215     229058
# 871      89522
# 409      50351
# 293      60520
# Name: Price, dtype: int64

# %%
X_test.head()
# Out:
#      Company  TypeName            Cpu  Ram             Gpu  \
# 1012     MSI    Gaming  Intel Core i7   16  Nvidia GeForce
# 230     Acer    Gaming  Intel Core i5    8  Nvidia GeForce
# 589     Dell  Notebook  Intel Core i5    4        Intel HD
# 80        HP  Notebook  Intel Core i5    8        Intel HD
# 132       HP  Notebook  Intel Core i7    8       Intel UHD
#
#                        OpSys  Weight  IPS  Touchscreen  Cpu_speed_GHz   HDD  \
# 1012              Windows 10    2.94    0            0            2.6  1000
# 230               Windows 10    2.50    1            0            2.5     0
# 589   Linux/Chrome OS/Others    1.93    0            0            2.6   500
# 80                Windows 10    1.63    0            0            1.6     0
# 132               Windows 10    1.63    0            0            1.8     0
#
#       SSD  PPI
# 1012  256  141
# 230   256  141
# 589     0  100
# 80    256  157
# 132   256  157

# %%
y_test.head()
# Out:
# 1012    169625
# 230      78891
# 589      81036
# 80       80197
# 132      92133
# Name: Price, dtype: int64

# %%
print(X_train.dtypes)
# Out:
# Company           object
# TypeName          object
# Cpu               object
# Ram                int64
# Gpu               object
# OpSys             object
# Weight           float64
# IPS                int64
# Touchscreen        int64
# Cpu_speed_GHz    float64
# HDD                int64
# SSD                int64
# PPI                int64
# dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from xgboost import XGBRegressor

# %%
#LinearRegression
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=LinearRegression()
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.8238378847206818
# RMSE:  29455.106801019643
# MAE:  21568.33241805269

# %%
#Ridge
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=Ridge(alpha=0.00001)
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.8238378550282598
# RMSE:  29455.109283373527
# MAE:  21568.331488167492

# %%
#Lasso
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=Lasso()
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.8238189818226753
# RMSE:  29456.687083883477
# MAE:  21559.77813403899

# %%
#KNeighborsRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=KNeighborsRegressor(n_neighbors=9,metric="euclidean")
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.6718903247561612
# RMSE:  40198.87156387256
# MAE:  27172.88888888889

# %%
#SVR
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=SVR(C=100000000)
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.7010872581047585
# RMSE:  38368.65343384642
# MAE:  24064.309890203946

# %%
#DecisionTreeRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.7679933120448109
# RMSE:  33802.94942863878
# MAE:  23391.579217679402

# %%
#RandomForestRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=RandomForestRegressor(n_estimators=200,max_depth=12)
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.7821984555802738
# RMSE:  32751.77343489637
# MAE:  20116.35466250305

# %%
#AdaBoostRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=AdaBoostRegressor()
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.6327425395910908
# RMSE:  42529.43928164505
# MAE:  33225.185876489195

# %%
#GradientBoostingRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(drop="first"),[0,1,2,4,5])],remainder="passthrough")
step2=GradientBoostingRegressor(n_estimators=500,max_depth=3)
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score: ",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE: ",mean_absolute_error (y_test,y_pred))
# Out:
# R2 score:  0.8172675728834731
# RMSE:  29999.371412950404
# MAE:  18214.15456673127

# %%
import pickle

# %%
pickle.dump(df,open("df.pkl","wb"))
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.9 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit  as st
import pickle
import numpy as np

df=pickle.load(open("df.pkl","rb"))
pipe=pickle.load(open("pipe.pkl","rb"))

st.title("Laptop Price Predictor App")
st.text("This app is created using the data available on kaggle.")
st.text("The prediction here is based on the data available, hence might not allign with real life data.")
company=st.selectbox("Manufacturing Company",df["Company"].unique(),index=4)
typename=st.selectbox("Type of Laptop",df["TypeName"].unique(),index=1)
cpu=st.selectbox("Processor",df["Cpu"].unique(),index=0)
ram=st.radio("RAM(in GB)",[4,6,8,12,16,24,32,64,128],index=2,horizontal=True)
gpu=st.selectbox("Graphics Card",df["Gpu"].unique(),index=1)
os=st.selectbox("Operating System",df["OpSys"].unique(),index=2)
weight=st.slider("Weight(in KG)",min_value=0.7,max_value=4.7,value=2.0,step=0.1)
ips=st.radio("IPS Display?",["Yes","No"],horizontal=True)
touchscreen=st.radio("Touchscreen?",["Yes","No"],horizontal=True)
cpu_speed=st.slider("CPU clock Speed",min_value=0.9,max_value=3.6,value=2.5,step=0.1)
hdd=st.radio("Hard drive capacity(in GB)[If SSD, set HDD value to 0]",[0,128,500,1000,2000],horizontal=True)
ssd=st.radio("SSD capacity(in GB)",[0,8,16,32,64,128,256,512,1000,2000],index=7,horizontal=True)
screen_size=st.slider("Screen size (measured in inches,calculated diagonally)",min_value=10.0,max_value=18.5,value=15.6,step=0.1)
screen_res=st.selectbox("Screen Resolution",["1366x768","1440x900","1600x900","1920x1080","1920x1200",
                                             "2160x1440","2256x1504","2304x1440","2400x1600","2560x1440",
                                             "2560x1600","2736x1824","2880x1800","3200x1800","3840x2160"],index=3)
if st.button("PREDICT PRICE"):
    ppi=None
    if (ips=="Yes"):
        ips=1
    else:
        ips=0
    if (touchscreen=="Yes"):
        touchscreen=1
    else:
        touchscreen=0
    X_res=int(screen_res.split("x")[0])
    Y_res=int(screen_res.split("x")[1])
    ppi=((X_res**2)+(Y_res**2))**0.5/screen_size

    query=np.array([[company,typename,cpu,ram,gpu,os,weight,ips,touchscreen,cpu_speed,hdd,ssd,ppi]])
    op=pipe.predict(query)
    f_op=int(round(op[0],-2))
    st.subheader("The estimated price of the laptop with the above selected configuration is ₹"+str(f_op))
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.0'
